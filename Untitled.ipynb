# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup

# %%
quote_page = 'https://www.zillow.com/homes/for_sale/Boston-MA-02126/59138273_zpid/58640_rid/42.300388,-71.060172,42.251615,-71.119309_rect/13_zm/'

# %%
req = urllib.request.Request(
    quote_page, 
    data=None, 
    headers={
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
    })

# %%
page = urlopen(req)

# %%
page_response = requests.get(quote_page, timeout=5)

# %%
soup = BeautifulSoup(page, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="wf-loading no-js zsg-theme-modernized zsg-lightbox_scroll" itemscope="" itemtype="http://schema.org/Organization" lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#" xmlns:product="http://ogp.me/product#">
# <head>
# <meta content="on" http-equiv="x-dns-prefetch-control"/><link href="//www.zillowstatic.com" rel="dns-prefetch"/><link href="//fonts.googleapis.com" rel="dns-prefetch"/><link href="//photos.zillowstatic.com" rel="dns-prefetch"/><link crossorigin="true" href="https://gdp.zillow.com/api/" rel="preconnect"/><link crossorigin="true" href="https://mortgageapi.zillow.com" rel="preconnect"/><meta charset="utf-8"/><title>19 Ellison Ave, Boston, MA 02126 | MLS #72367172 | Zillow</title><meta content="19 Ellison Ave , Boston, MA 02126 is a single-family home listed for-sale at $699,900. The 1,772 sq. ft. home is a 5 bed, 3.0 bath property. Find 6 photos of the 19 Ellison Ave home on Zillow. View more property details, sales history and Zestimate data on Zillow. MLS # 72367172" name="description"/><meta content="Zillow, Inc." name="author"/><meta content="Copyright (c) 2006-2017 Zillow, Inc." name="Copyright"/><script>var UI_INIT_AT = Date.now ? Date.now() : +(new Date());</script><link href="https://www.zillowstatic.com/static-zsg/9c6fb5d/static-zsg/zsg/z-fonts/gotham/gotham.css" media="all" rel="stylesheet" type="text/css"/><script>document.documentElement.className = document.documentElement.className.replace(/\bwf-loading\b/g, '');</script><link href="https://www.zillowstatic.com/static-zsg/9c6fb5d/static-zsg/zsg/zsg-core.css" media="all" rel="stylesheet" type="text/css"/><link href="https://www.zillowstatic.com/static-zsg/9c6fb5d/static-zsg/zsg/zsg-opt.css" media="all" rel="stylesheet" type="text/css"/><script>document.documentElement.className += ' gotham-test'</script><link href="https://www.zillowstatic.com/cdp/b582139/dist/community-details/css/community-details-a45e9befc9.css" media="all" rel="stylesheet" type="text/css"/><link href="https://www.zillowstatic.com/static-reg-login/LIVE/reg-login/css/reg-login-6c2eeaca75.css" media="all" rel="stylesheet" type="text/css"/><link href="https://www.zillowstatic.com/static-user-actions/LIVE/share-home/css/share-home-b11d8339cc.css" media="all" rel="stylesheet" type="text/css"/><link href="https://www.zillow.com/static-mortgage/calculator/payment/hdp/css/payment-calculator-hdp-16e81d9f9d.css" media="all" rel="stylesheet" type="text/css"/><link href="https://www.zillow.com/static-mortgage/calculator/payment/hdp-summary/full/hdp-payment-calculator-summary-full-fc6e41d3ce.css" media="all" rel="stylesheet" type="text/css"/><link href="https://www.zillow.com/static-mortgage/after-bal-contact/css/after-bal-contact-59216a137a.css" media="all" rel="stylesheet" type="text/css"/><link href="https://www.zillowstatic.com/hdp/cd6838f/home-details/css/home-details-d878ef1b59.css" media="all" rel="stylesheet" type="text/css"/><link href="https://www.zillowstatic.com/static-zestimate/LIVE/zestimate-summary/css/zestimate-summary-205437e5c9.css" media="all" rel="stylesheet" type="text/css"/><link href="https://www.zillowstatic.com/s/?static.b20c067=css/z-modules/header.css,css/z-modules/lightbox-blocks.css,css/z-modules/breadcrumb.css,css/z-pages/static-split-hdp.css,css/z-modules/hdp-component-prop-notes.css,css/z-modules/hdp-home-expenses.css&amp;static-search.cc047d4=css/search-hdp-lightbox.css,css/collection-discovery.css,css/user-uss-lightbox.css,css/search-subnav.css,css/search-list.css,css/search-page-ads.css,css/photo-card.css,css/collection-inline-list-content.css,css/search-map.css,css/map-bubble.css,css/tabview-simple.css,css/map-button-addon-layers.css,css/search-affordability-filter-exposed.css,css/search-layout.css&amp;static-claim.a2ad0b8=css/z-modules/home-owner-claim.css&amp;static-topnav.516acd4=css/z-modules/top-nav.css,css/z-modules/top-nav-hoverable.css,css/z-modules/top-nav-wide.css,css/z-modules/top-nav-wide_ACT-994.css,css/z-modules/tengage-upsells.css,css/z-modules/sub-nav-wide.css&amp;static-map.d81c3c9=css/map-button.css,css/z-modules/search-map-type-control.css&amp;static-schools.18d5a82=css/z-modules/schools-nearby-schools.css,css/z-modules/schools-great-school-badges.css,css/ ...
# window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
# </script><script>if(typeof ZILLOW==="undefined"){var ZILLOW={}}(function(w,d){if(top!=self){top.location.replace(self.location.href)}var h=d.getElementsByTagName("html")[0];h.className=h.className.replace(/(?:^|\s)no-js(?!\S)/g,"");var l=w.location,a=l.hash,sn,snr=/scrnnm=[^&\}]+/;if(a&&a.indexOf("scrnnm")>0&&(sn=a.match(snr)[0])){a=l.hash.replace(snr,"");a=a.replace(/&&/,"&").replace(/\{&/,"{").replace(/&\}/,"}").replace(/\{\}/,"");w.location=l.protocol+"//"+l.host+l.pathname+(l.search?l.search+"&"+sn:"?"+sn)+a}ZILLOW.facebookSdkUrl="//connect.facebook.net/en_US/all.js";
# /*@cc_on
#             var q=d.createElement('div');q.innerHTML='<z>i</z>';q.childNodes.length!==1&&('abbr article aside audio canvas details figcaption '+
#             'figure footer header hgroup mark meter nav output progress section summary time video').replace(/\w+/g,function(n){d.createElement(n)});
#             @*/
# })(this,document);var pageName="Search:HomeDetailService";var requestId="b2dnCk4gS0uY7Wh2_xERDg";var oldErr=window.onerror,CP_ERROR_LIMIT=5;window.cpErrors=0;window.onerror=function(i,d,b){if(CP_ERROR_LIMIT>cpErrors){try{cpErrors++;i=i&&i.toString().substring(0,1750);var f="/ui/ClientProblem.htm",a="c=uncaught&m="+encodeURI(i)+"&u="+encodeURI(d)+"&l="+encodeURI(b)+"&r="+encodeURI(document.referrer)+"&p="+encodeURI(pageName)+"&o="+encodeURI(requestId),h,c;h=f+"?"+a;c=new Image().src=h;if(window.zonLog){window.zonLog("Unhandled Error: "+h)}if(console&&console.error){console.error("Unhandled error found. "+i+" "+d+" "+b+" "+document.referrer)}if(oldErr){return oldErr(errorMsg,d,lineNumber)}return false}catch(g){if(console&&console.error){console.error("Couldn't log error.",g)}}}};if(document.addEventListener){document.addEventListener("DOMContentLoaded",function ProfileDOMContentLoadedEvent(a){ClientProfiler.profile("DOMContentLoaded");setTimeout(function(){if(ga&&performance&&typeof performance.getEntriesByName==="function"&&performance.getEntriesByName("DOMContentLoaded").length>0){ga("set","dimension72",parseFloat(performance.getEntriesByName("DOMContentLoaded")[0].startTime.toString()).toFixed(2))}},2000);document.removeEventListener("DOMContentLoaded",ProfileDOMContentLoadedEvent)})}if(window.addEventListener){window.addEventListener("load",function ProfileLoadEvent(a){ClientProfiler.profile("native browser onload");setTimeout(function(){if(ga&&performance&&typeof performance.getEntriesByName==="function"&&performance.getEntriesByName("native browser onload").length>0){ga("set","dimension73",parseFloat(performance.getEntriesByName("native browser onload")[0].startTime.toString()).toFixed(2))}},2000);window.removeEventListener("load",ProfileLoadEvent)})}ZILLOW.PROFILER_ACTIVE=true;var _gaq=_gaq||[],_gaqBackup=_gaqBackup||[];</script><script>if(typeof ClientProfiler!=="undefined"){ClientProfiler.profile("css finished")};</script><link href="https://www.zillowstatic.com/static-zsg/9c6fb5d/static-zsg/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/><script>
#         (function(z,c,m){m=z[c]={};m.queue=[];m.add=function(a){m.queue.push(a)}})(window,'ZCM');
#     </script><link href="/manifest.json" rel="manifest"/><script async="" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js"></script></head>
# <body class="map-list search-page page-list-standard zsg-layout_full hdp-collapse hotel-california building-hotel-california hide-top-nav-gleam lightboxed list-narrow-default tengage wide">
# <script type="text/javascript"><!--
#
#
# 		window.ZILLOW_BASE_URL = window.ZILLOW_BASE_URL || {};
# 		window.ZILLOW_BASE_URL.zrm = "https://www.zillow.com:443/rental-manager/";
#
#
# // --></script><script>new Image().src = 'https://www.zillow.com/ui/JavascriptEnabled.htm?guid=4d0f43c8e91640dbbcae24ceb3ee5cc5&zPage=Search%3AHomeDetailService&hostId=6Vj01_CWc0yWoTxvLM72IQ&time=' + Date.now();</script><svg style="display:none" xmlns="http://www.w3.org/2000/svg"><symbol id="logo-text-svg" viewbox="0 0 100 100"><path d="M61.2 81.8c1.1-1.2 1.5-2.6 1.5-4.7c0-2-0.4-3.3-1.4-4.5c-1.1-1.2-2.4-1.8-4.2-1.8c-3.3 0-5.5 2.6-5.5 6.4 c0 3.9 2.2 6.4 5.5 6.4C59 83.5 60.3 82.9 61.2 81.8z M58.6 73.7c0.4 0.6 0.7 1.6 0.7 3.3c0 2.9-0.6 4.1-2 4.1c-0.6 0-1.3-0.3-1.6-1 c-0.3-0.6-0.4-1.7-0.4-3.1c0-1.2 0.1-2.1 0.3-2.7c0.3-0.8 0.9-1.2 1.7-1.2C57.8 73.1 58.3 73.3 58.6 73.7z M76.8 83.2L80.4 71H77 l-0.9 4.4c-0.3 1.6-0.6 3.5-0.7 4c0 0-0.4-2.1-0.9-4.3l-1-4.1h-3l-1.2 4.1c-0.6 2.1-0.9 4.3-0.9 4.3S68 77 67.7 75.5l-1-4.6h-3.3 l3.4 12.3h3l0.6-2.5c0.3-1.1 0.8-3.3 1.1-4.3c0.2-0.9 0.2-1.1 0.3-1.6c0.1 0.5 0.1 0.6 0.2 1.2c0.1 0.8 0.4 2 0.7 3l1.1 4.2H76.8z M45.8 83.2h3.3l0-17.7l-3.3 0.7L45.8 83.2z M39.4 83.2h3.3l0-17.7l-3.3 0.7L39.4 83.2z M33 83.3h3.2l0-11.5L33 72.5L33 83.3z M34.6 71c1.1 0 2-0.9 2-2c0-1.1-0.9-2-2-2c-1.1 0-2 0.9-2 2C32.7 70.2 33.6 71 34.6 71z M30 83.2l0.9-2.7h-5.6l-1.4 0 c0 0 0.3-0.5 0.6-1.1l6.4-11.1v-2.4h-10L20 68.7h5.2c1 0 1.4 0 1.4 0s-0.2 0.6-0.7 1.4l-6.3 10.8v2.3H30z"></path></symbol><symbol id="logo-house-svg" viewbox="0 0 100 100"><path d="M30 48.8c4.9-5.1 22.6-21.5 22.6-21.5c-9.2 2.2-18.8 5.1-22.3 6.7l-5.2 5.3c4.3-0.9 5.7-1.1 8.9-1.6L30 48.8z M62.8 23.2c0 0-15.6 15.8-18.1 18c4.8-1.7 14.5-3.8 20.7-4.1c0.7-2.2 1.5-3.8 1.5-3.8l8.3-0.8C75.2 32.5 68.9 27.4 62.8 23.2z M27.3 56.3c1.8-0.8 18.6-6.4 34.1-7.3c0.3-1.3 2-5.7 2.3-6.9c-16.1 1.1-29.1 6-34.4 8.4L27.3 56.3z M52.4 16.3 c-2.8 1.3-10.8 7.5-15.1 10.7c5.2-1.8 17.8-4.6 24.3-4.7C59.6 20.9 53.9 17.1 52.4 16.3z"></path></symbol></svg><script>if(typeof ClientProfiler!=="undefined"){ClientProfiler.profile("html body started")};</script><a id="top" name="top"></a><noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-P6HT97" style="display:none;visibility:hidden" width="0"></iframe></noscript><div class="main-wrapper hdp-lightboxed" id="wrapper"><div class="zsg-modal-mask"></div><header class="zss-header pinnable-header zsg-layout-width layout-width_marginless"><nav class="nav-top nav-top_full " role="navigation"> <a accesskey="1" class="zsg-logo za-track-event" data-za-action="Zillow logo click" data-za-category="TopNav" data-za-label="" href="https://www.zillow.com/" title="Zillow Real Estate"><svg class="zsg-logo-svg"><use class="zsg-logo-house" xlink:href="#logo-house-svg"></use><use class="zsg-logo-text" xlink:href="#logo-text-svg"></use></svg></a><svg style="display:none" xmlns="http://www.w3.org/2000/svg"><symbol id="logo-text-svg" viewbox="0 0 100 100"><path d="M61.2 81.8c1.1-1.2 1.5-2.6 1.5-4.7c0-2-0.4-3.3-1.4-4.5c-1.1-1.2-2.4-1.8-4.2-1.8c-3.3 0-5.5 2.6-5.5 6.4 c0 3.9 2.2 6.4 5.5 6.4C59 83.5 60.3 82.9 61.2 81.8z M58.6 73.7c0.4 0.6 0.7 1.6 0.7 3.3c0 2.9-0.6 4.1-2 4.1c-0.6 0-1.3-0.3-1.6-1 c-0.3-0.6-0.4-1.7-0.4-3.1c0-1.2 0.1-2.1 0.3-2.7c0.3-0.8 0.9-1.2 1.7-1.2C57.8 73.1 58.3 73.3 58.6 73.7z M76.8 83.2L80.4 71H77 l-0.9 4.4c-0.3 1.6-0.6 3.5-0.7 4c0 0-0.4-2.1-0.9-4.3l-1-4.1h-3l-1.2 4.1c-0.6 2.1-0.9 4.3-0.9 4.3S68 77 67.7 75.5l-1-4.6h-3.3 l3.4 12.3h3l0.6-2.5c0.3-1.1 0.8-3.3 1.1-4.3c0.2-0.9 0.2-1.1 0.3-1.6c0.1 0.5 0.1 0.6 0.2 1.2c0.1 0.8 0.4 2 0.7 3l1.1 4.2H76.8z M45.8 83.2h3.3l0-17.7l-3.3 0.7L45.8 83.2z M39.4 83.2h3.3l0-17.7l-3.3 0.7L39.4 83.2z M33 83.3h3.2l0-11.5L33 72.5L33 83.3z M34.6 71c1.1 0 2-0.9 2-2c0-1.1-0.9-2-2-2c-1.1 0-2 0.9-2 2C32.7 70.2 33.6 71 34.6 71z M30 83.2l0.9-2.7h-5.6l-1.4 0 c0 0 0.3-0.5 0.6-1.1l6.4-11.1v-2.4h-10L20 68.7h5.2c1 0 1.4 0 1.4 0s-0.2 0.6-0.7 1.4l-6.3 10.8v2.3H30z"></path></symbol><symbol id="logo-house-svg" viewbox="0 0 100 100"><path d="M30 48.8c4.9-5.1 22.6-21.5 22.6-21.5c-9.2 2.2-18.8 5.1-22.3 6.7l-5.2 5.3c4.3-0.9 5.7-1.1 8.9-1.6L30 48.8z M62.8 23.2c0 0-15.6 15.8-18.1 18c4.8-1.7 14.5-3.8 20.7-4.1c0.7-2.2 1.5-3.8 1.5-3.8l8.3-0.8C75.2 32. ...
#         window.setTimeout(function preventPageResourceLoadCancelOnEsc() {
#             var prevOnKeyDown = document.onkeydown,
#                 newOnKeyDown = function(evt) {
#                     if (evt.keyCode == 27) {
#                         evt.preventDefault();
#                     }
#                     if(typeof prevOnKeyDown == "function") {
#                         prevOnKeyDown(evt);
#                     }
#                 },
#                 loadListener = window.addEventListener("load", function() {
#                     if(document.onkeydown === newOnKeyDown) {
#                         document.onkeydown = prevOnKeyDown;
#                     }
#                 });
#             document.onkeydown = newOnKeyDown
#         }, 1);
#     </script><div class="yui3-widget yui3-lightbox yui3-widget-positioned yui3-widget-stacked yui3-lightbox-modal yui3-lightbox-focused" id="search-detail-lightbox" style="z-index: 10010;" tabindex="-1"><div class="dialog yui3-lightbox-content" id="search-detail-lightbox_content"><div class="yui3-widget-bd lightbox-body zsg-tooltip-viewport"><div class="zsg-lightbox-content yui3-widget-stdmod" id="search-detail-lightbox-content"><div id="hdp-lightbox-action-bar-container"><div id="hdp-action-bar-container"><div class="zsg-toolbar" id="actionBar"><!-- --><ul class="zsg-toolbar-left"><li id="contact-menu"><div class="template hide" id="contact-lightbox_src"><!--<div id="contact\-lightbox_content" class="ajax\-form  dialog clearfix"><a class="close lightbox\-close zsg\-icon\-x\-thin" title="Close" tabindex="\-1"></a><div class="yui3\-widget\-bd lightbox\-body clearfix"><div id="contact\-lightbox\-confirm" class="lightbox\-block current"><div class=" generic\-box yui3\-widget\-stdmod module"><div class="module\-body yui3\-widget\-bd clearfix"><div class="cf\-bal\-container">  <div class="bal\-refactor      bal">  <h2 class="form\-title">Contact Agent</h2>   <form id="lead\-form_contact\-lightbox" action="https://www.zillow.com/contact/ContactSubmit.htm" class="cfjs\-form multi\-zuid\-select zsg\-form validation\-above contact\-lightbox" method="get">        <hr class="cf\-recipients\-separator zsg\-separator zsg\-content\-item  hide"/><div class="column recipients hide  " data\-test\-id="cf\-recipients">  <div class="signature\-refactor  zpro   " data\-zuid="X1\-ZUway8sk20eqdl_6ttic"><div class="zsg\-form\-field zsg\-form\-field_checkbox sig\-col ">   <input id="contact\-lightbox\-X1\-ZUway8sk20eqdl_6ttic" name="zuids" value="X1\-ZUway8sk20eqdl_6ttic" class="radio cf\-selectable\-zuid" agenttype="" type="radio"  group="cf\-zuids"/><label for="contact\-lightbox\-X1\-ZUway8sk20eqdl_6ttic">   <div class="photo sig\-col">  <img alt="Profile picture for Traci Hartford Almeida" src="https://www.zillowstatic.com/static/images/nophoto_h_n.png" width="60px" height="60px" class="zsg\-image\-profile"/></div>  </label>  </div>    <span class="contact\-badge Listing Agent">Listing Agent</span>      <div class="info flat\-star\-ratings sig\-col">  <span class="snl name notranslate"><a href="/profile/Traci\-Hartford\-Almeida/" class="profile\-name\-link">Traci Hartford Almeida</a></span>     <span class="snl lender\-rating\-large">   <a href="/profile/Traci\-Hartford\-Almeida/#reviews" class="rating"><span class="zsg\-rating r000 zsg\-rating_000"></span></a>       <span class="reviews">(<a href="/profile/Traci\-Hartford\-Almeida/#reviews">0</a>)</span>   </span>     <span class="snl past\-sales">  <a href="/profile/Traci\-Hartford\-Almeida/"><span class="sales\-count">0</span> Recent sales</a>   </span>         <span class="snl phone">(774) 297\-9779 </span>    </div>   <span class='hide agent\-type'>Listing Agent</span>    <span class='hide first\-name'>Traci Hartford</span>    </label>  </div>  <div class="signature\-refactor     " data\-zuid="X1\-ZU12ek9l9fycxzd_8l13l"><div class="zsg\-form\-field zsg\-form\-field_checkbox sig\-col ">   <input id="contact\-lightbox\-X1\-ZU12ek9l9fycxzd_8l13l" name="zuids" value="X1\-ZU12ek9l9fycxzd_8l13l" class="radio cf\-selectable\-zuid" agenttype="" type="radio"  group="cf\-zuids"/><label for="contact\-lightbox\-X1\-ZU12ek9l9fycxzd_8l13l">   <div class="photo sig\-col">  <img alt="Profile picture for Denise Monteiro" src="https://photos.zillowstatic.com/h_n/ISme9jj5qyyggi0000000000.jpg" width="60px" height="60px" class="zsg\-image\-profile"/></div>  </label>  </div>    <span class="contact\-badge Premier Agent">Premier Agent</span>      <div class="info flat\-star\-ratings sig\-col">  <span class="snl name notranslate"><a href="/profile/Denise\-Monteiro/" class="profile\-name\-link">Denise Monteiro</a></span>     <span class="snl lender\-rating\-large">   <a href="/profile/Denise\-Monteiro/#reviews" class= ...
#
#                         </textarea></p><ul class="zsg\-list_inline"><li><a href="/myzillow/UpdateFavorites.htm?zpid=59138273&operation=saveNote&ajax=false" rel="nofollow" data\-fm\-zpid="59138273" data\-fm\-callback="windowReloadSuccessHandler" data\-fm\-redirect="true" data\-fm\-save\-note="true" data\-after\-auth\-action\-type="Event" data\-after\-auth\-global\-event="favoriteManager:addFavoriteProperty" data\-target\-id="register" tabindex="10" data\-za\-label="hdp\-save\-as\-favorite\-note" class="save\-home\-operation zsg\-button_primary" id="register_opener_1"><span>Save</span></a></li><li><a data\-fm\-zpid="59138273" href="#" class="delete\-hdp\-fav\-note fm\-remove\-note zsg\-button_primary hide">Delete this note</a></li></ul><p class="one\-click\-error\-msg\-container hide">&nbsp;</p><p id="noteSaved59138273" class="note\-saved hide"></p></div></div></div></div></div>--></div></input></li><!--Modernize: This case is no longer used?--><li class="hide-when-property-hidden default-ids hide new-email" data-zpid="59138273"><a class="show-lightbox zsg-toolbar-button zsg-button" data-zpid="59138273" href="#send-to-friend-lightbox"><span class="zsg-icon-mail"></span>Share <span class="default-email-ids"></span></a></li><li id="share-home-refactor-node"></li><input id="ShareHomeProxiedReactAppGlobalConfig" type="hidden" value='{"rawHTML":"&lt;div id=\"act-share-home-app\"&gt;&lt;/div&gt;","styleSheets":["https://www.zillowstatic.com/static-user-actions/LIVE/share-home/css/share-home-b11d8339cc.css"],"scripts":["https://www.zillowstatic.com/static-user-actions/LIVE/overall-commons-460b7be054.js","https://www.zillowstatic.com/static-user-actions/LIVE/share-home/app-a6ea5a2104.js"],"config":"ShareHomeProxiedReactAppGlobalConfig={\"openOnLoad\":\"false\",\"postShareSignin\":\"false\",\"city\":\"Boston\",\"saved\":\"false\",\"zpid\":\"59138273\",\"defaultEmailAFriendMessage\":\"Check out this home I found on Zillow.\",\"className\":\"show-lightbox zsg-toolbar-button zsg-button\",\"captchaPublicKey\":\"6Lf2nvMSAAAAAMQ5p6WlAfDEixMdOQgJsij-3_ud\",\"zipcode\":\"02126\",\"csrfToken\":\"Mpz4vdGBX4mLsNn7k7Nq8ehEwt6sfatFRIXRbB7kR7s\",\"streetAddress\":\"19 Ellison Ave \",\"loggedIn\":\"false\",\"state\":\"MA\"}"}'/><input id="zillow-static-domain" type="hidden" value="https://www.zillowstatic.com/"/><div class="template hide" id="send-to-friend-lightbox_src"><!--<div id="send\-to\-friend\-lightbox_content" class="shareable ajax\-form email\-a\-friend dialog clearfix"><a class="close lightbox\-close zsg\-icon\-x\-thin" title="Close" tabindex="\-1"></a><div class="yui3\-widget\-bd lightbox\-body clearfix"><div id="send\-to\-friend\-lightbox\-confirm" class="lightbox\-block current"><div id="send\-to\-friend"><h2>Email this home</h2><form action="/email/EmailAFriendRequest.htm" class="lead\-form zsg\-separator zsg\-content\-item"><div class="ajax\-form\-content"><div class="captcha\-field zsg\-form\-field"><p>Please complete the Captcha below.</p><div id="send\-to\-friend\-recaptcha"></div><p class="zsg\-form\-error\-text">There was an issue with the captcha result.<br/>Please try again.</p></div><div class="zsg\-form\-field"><label for="remail" class="email\-a\-friend\-label">Recipient's email</label><input multiple="5" name="remail" id="remail" placeholder="Enter email" type="email" title="Please enter up to five valid email addresses, separated by commas." class="required" required="required"></input><p class="zsg\-form\-help\-text">Separate multiple addresses with a comma.</p></div><div class="zsg\-form\-field"><label for="semail" class="email\-a\-friend\-label">Your email</label><input name="semail" id="semail" placeholder="Enter email" type="email" title="Please enter a valid email address." class="required" required="required"></input></div><div class="zsg\-form\-field"><label for="smsg" class="email\-a\-friend\-label">Include message <span class="de\-emph">(optional)</span></label><textarea id="smsg" name="smsg" maxlength="2000" data\ ...
#                 {"@context":"http://schema.org/","@type":"Product","name":"19 Ellison Ave, Boston, MA 02126","offers":{"@type":"Offer","price":699900,"priceCurrency":"USD"}}
#             </script><div class="zsg-g zsg-g_gutterless"></div><div class="hdp-content-wrapper zsg-content-section" role="main"><div class="zsg-lg-2-3 zsg-sm-1-1 hdp-header-description"><header class="zsg-content-header addr"> <h1 class="notranslate">19 Ellison Ave, <span class="zsg-h2 addr_city">Boston, MA 02126</span> </h1> <h3 class=""> <span aria-hidden="true" class="middle-dot"> </span><span class="addr_bbs">5 beds</span><span aria-hidden="true" class="middle-dot"> </span><span class="addr_bbs">3 baths</span><span aria-hidden="true" class="middle-dot"> </span><span class="addr_bbs">1,772 sqft</span> </h3> </header></div><div class="zsg-lg-1-3 zsg-md-1-1 hdp-summary"><div class=" " id="home-value-wrapper"><div class="estimates"> <div class=" status-icon-row for-sale-row home-summary-row"> <span class="zsg-icon-for-sale for-sale" data-icon-class="zsg-icon-for-sale" id="listing-icon"></span>  For Sale <span class=""> <span class="value-suffix"> </span></span> </div> <div class="main-row home-summary-row"> <span class=""> $699,900 <span class="value-suffix"> </span></span> </div> <div class=" home-summary-row"> <span class="zsg-tooltip-launch zsg-tooltip-launch_keyword" data-target-id="zest-tip-hdp">Zestimate<sup>®</sup>:</span> <span class=""> $585,945 <span class="value-suffix"> </span></span> </div> <div class=" home-summary-row"> <span class=""> <span class="value-suffix"> </span></span> <a class="za-track-event show-home-value" data-za-action="View Zestimate Details Click" data-za-category="Homes" data-za-label="WithZestimate" href="javascript: void(0);"> View Zestimate details </a> </div> </div> <div class="loan-calculator-container"><div data-15-yr="3.798" data-30-yr="4.39" data-5-1="3.915" id="zmm-current-rates"></div><div data-loan-type-purchase="true" data-property-city="Boston" data-property-hdp-url="https://www.zillow.com/homedetails/19-Ellison-Ave-Boston-MA-02126/59138273_zpid/" data-property-image="https://photos.zillowstatic.com/p_e/ISecq8u6lh2gn41000000000.jpg" data-property-value="699900" data-property-zipcode="02126" data-show-upsell="true" data-street-address="19 Ellison Ave" data-type="Single Family" id="loan-calculator-data"><div class="zmm-api-config template hide"><!--{"stateAbbreviationLookupFailed":false,"zipcode":"94582","abs":{"MortgageEmailPlacementSignUpTest":"BOTTOM_OF_LOAN_REQUEST_POP_UP_2","MortgageDropdownTitle":"TITLE_MORTGAGES","MortgageHDPCreditscoreUpsell":"ENABLED","MortgageLoanPurposeToggle":"BUTTONS","MortgageQuoteCard":"NEW","MortgageCalcConvPage":"V4","MortgageModernQDP":"MODERN_INLINE","MortgageQuoteBadges":"ON","MortgageResponsiveShopping":"ENABLED","MortgageStaticPageWrapper":"STATIC","MortgageUpsellTestingHDP":"SEE_CURRENT_RATES","MortgageTopNavPriority":"LONGFORM","MortgageAdvertise":"Post_Google","MortgageSubnav":"FIND_A_LENDER","MortgageMobilePreApproval":"PreApproval_OFF","MortgageShoppingWizardV2":"UNIFIED","MortgageHDPUpsell":"ZLF","MortgageStackNouveauZCQ":"ENABLED","MortgageQuotesOnHDP":"AUTO_QUOTE_INLINE_CUSTOM","MortgageQDPConversionTake2":"ACTION_BUTTONS","MortgageBrowseReact":"REACT","MortgagePreapprovalLandingPage":"ALL_ON","MortgageModernAffordabilityCalculator":"MODERN","MortgageABC":"MULTISLIDE_ASSUME","MortgageModernRefinanceCalculator":"MODERN","MortgageHDPModule":"REACT_CALCULATOR_BUTTON","MortgageSponsoredQuotes":"FEATURED_QUOTES","MortgageFeeUpdates":"Lender_Credit","Mortgage_HomeAffordabilityFilter":"ENABLED","MortgageStackNouveauZLF":"ENABLED","MortgageHeaderFooterRefresh":"FOOTER","MortgageQDPStickybar":"STICKYBAR","MortgagePaidInFull":"PAID_IN_FULL","MortgageUsingMAX":"ON","MortgagePreapprovalUpsell":"TOP_NAV_ONLY","MortgageStackNouveau":"CLIENT","MortgageHDPModuleLFTab":"SAME_TAB","MortgagePreapprovalFlow":"MULTI_STEP_CREDIT_ASK_CONTACT_BEFORE_DOWN_NO_LENDER_SELECTION","MortgageModernShopping":"MODERN_3","MortgageBorrowerReengagementEmail":"ChartOnly","MortgageHDPSummaryCalc":"LW_CALC_GET_PREQUALIFIED","MortgageMobileAppUpsellIOS":"FullScreenWhite","Mortg ...
# <section class="zsg-content-component">
# <div class="region-homevalues">
# <div class="zsg-g">
# <div class="region-homevalues-zestimate zsg-lg-1-3 zsg-md-1-2 zsg-sm-1-1 zsg-content-component">
# <div class="zsg-g">
# <div class="zsg-lg-1 zsg-md-1 zsg-sm-1-2">
# <h4>
# <span class="large-viewport">Median</span>
# <span class="small-viewport">Med.</span>
#                                 Zestimate <a class="zsg-tooltip-launch zsg-icon-circle-question" href="#tt-med-zest"></a>
# </h4>
# <h2 class="zsg-content_collapsed">$400,600</h2>
# <div class="zsg-tooltip" id="tt-med-zest">
# <p>The median Zestimate valuation for a given geographic area on a given day is the <strong>Zillow Home Value Index. </strong><a href="https://www.zillow.com/info/whats-the-zillow-home-value-index/" title="What's the Zillow Home Value Index?">Learn more</a></p>
# </div>
# </div>
# <div class="zsg-lg-1 zsg-md-1 zsg-sm-1-2">
# <div class="zsg-media">
# <span class="zsg-icon-circle-arrow-up zsg-media-img"></span>
# <div class="zsg-media-bd">
# <h5 class="zsg-content_collapsed">9.9% </h5>
# <p class="zsg-fineprint">Past 12 months </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div class="za-track-event zsg-content-component notranslate" data-za-action="Market Guide - expand" data-za-category="Homes">Zillow predicts  <a href="/mattapan-boston-ma/home-values/">Mattapan home values</a> will increase 4.4% next year, compared to a 4.4% rise for Boston as a whole. Among Mattapan homes, this home is 80.3% more expensive than the midpoint (median) home, and is priced 44.9% more per square foot.<div class="hdp-neighborhood-subheader"><ul class="walkscore" id="walkscore-target"></ul></div></div><div class="homeMarkerData template hide"><!--["HouseSmallRed","https://photos.zillowstatic.com/p_a/ISecq8u6lh2gn41000000000.jpg",42277557,\-71073705]--></div><div id="neighborhood-map"><div id="inner-map-container"><div class="hdp-list map-view zsg-lg-1-1" id="map-view"><h4>Neighborhood Map</h4><div class="map-container" id="map-container"><div class="map-parent-container" id="hdp-map-parent-container"></div></div></div><div class="zsg-g"><div class="zsg-lg-1-1"><h4>Nearby Homes</h4><div class="hdp-unit-list nearby-homes-list" id="hdp-unit-list"><ul class="nearby-homes-carousel zsg-carousel_uninitialized"><li><article class="zsg-photo-card photo-card zsg-aspect-ratio type-not-favorite" data-grouped="" data-latitude="42277453" data-longitude="-71073670" data-pgapt="Zestimate" data-photocount="0" data-sgapt="Unknown Listed By" data-zillowowned="" data-zpid="59138274" id="zpid_59138274"><div class="zsg-photo-card-content zsg-aspect-ratio-content" itemscope="" itemtype="http://schema.org/SingleFamilyResidence"><span class="hide" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span itemprop="streetAddress">23 Ellison Ave</span><span itemprop="addressLocality"> Boston </span><span itemprop="addressRegion">MA </span><span class="hide" itemprop="postalCode">02126</span></span><span itemprop="geo" itemscope="" itemtype="http://schema.org/GeoCoordinates"><meta content="42.277453" itemprop="latitude"/><meta content="-71.07367" itemprop="longitude"/></span><div class="zsg-photo-card-caption"><h4 class="zsg-photo-card-spec"><span class="zsg-photo-card-status"><span class="zsg-icon-off-market"></span>Off Market</span></h4><p class="zsg-photo-card-spec"><span class="zsg-photo-card-price">$519,196</span><span class="zsg-photo-card-info">4 bds <span class="interpunct">·</span> 1.5 ba <span class="interpunct">·</span> 1,590 sqft</span></p><p class="zsg-photo-card-spec"><span class="zsg-photo-card-address">23 Ellison Ave, Boston, MA</span></p></div><a class="zsg-photo-card-overlay-link routable hdp-link noroute routable mask hdp-link" href="/homedetails/23-Ellison-Ave-Boston-MA-02126/59138274_zpid/"></a><div class="zsg-photo-card-img"><ul class="zsg-list_inline zsg-photo-card-badge"></ul></div><div class="zsg-photo-card-actions lh-hide "><a class="save-home-operation" data-address="23 Ellison Ave , Boston, MA 02126" data-after-auth-action-type="Event" data-after-auth-global-event="favoriteManager:addFavoriteProperty" data-auth-process="hdpnearbyhomes/save" data-fm-callback="claimHomeSuccessHandler" data-fm-zpid="59138274" data-save-home-reg-success-handler="resultListSaveFavoriteSuccessHandler" data-show-home-owner-lightbox="true" data-target-id="register" data-za-label="Save Map:List" href="/myzillow/UpdateFavorites.htm?zpid=59138274&amp;operation=add&amp;ajax=false" id="register_opener_5" rel="nofollow" title="Save this home"><span class="image-control sprite-heart-line new-save-hide-icon larger-save"></span></a></div></div><div class="minibubble template hide"><!--{"bed":4,"miniBubbleType":1,"image":"","sqft":1590,"label":"$519K","isPropertyTypeVacantLand":false,"datasize":8,"title":519196,"bath":1.5}--></div></article></li><li><article class="zsg-photo-card photo-card zsg-aspect-ratio type-not-favorite" data-grouped="" data-latitude="42277661" data-longitude="-71073741" data-pgapt="Zestimate" data-photocount="0" data-sgapt="Unknown Listed By" data-zillowowned="" data-zpid="59138272" id="zpid_59138272"><d ...
# <div>
# <p>Historically, GreatSchools ratings have been based solely on a comparison of standardized test results for all schools in a given state. As of September 2017, the GreatSchools ratings also incorporate additional information, when available, such as college readiness, academic progress, advanced courses, equity, discipline and attendance data. GreatSchools ratings are designed to be a starting point to help parents compare schools, and should not be the only factor used in selecting the right school for your family.</p>
# <p><strong>Disclaimer:</strong> School attendance zone boundaries are supplied by <a href="http://www.maponics.com/" rel="nofollow" target="_blank">Maponics</a> and are subject to change. Check with the applicable school district prior to making a decision based on these boundaries.</p>
# </div>
# </div>
# <div class="zsg-tooltip" id="great-school-rating-tip">
# <div>
#         Historically, GreatSchools ratings have been based solely on a comparison of standardized test results for all schools in a given state. As of September 2017, the GreatSchools ratings also incorporate additional information, when available, such as college readiness, academic progress, advanced courses, equity, discipline and attendance data. GreatSchools ratings are designed to be a starting point to help parents compare schools, and should not be the only factor used in selecting the right school for your family.<a href="https://www.greatschools.org/gk/ratings/"> Learn More.</a>
# </div>
# </div>
# <div class="zsg-content-item">
# <ul class="nearby-schools-list">
# <li class="nearby-schools-header">
# <h4 class="nearby-schools-rating">GreatSchools Rating
#                 <a class="zsg-tooltip-launch zsg-icon-circle-question" href="#great-school-rating-tip"></a>
# </h4>
# <div class="nearby-schools-info">
# <h4 class="nearby-schools-name zsg-sm-hide"> </h4>
# <h4 class="nearby-schools-grades zsg-sm-hide">Grades</h4>
# <h4 class="nearby-schools-distance zsg-sm-hide">Distance</h4>
# </div>
# </li>
# <li class="nearby-school clearfix">
# <div class="nearby-schools-rating">
# <span class="gs-rating-number gs-rating-3">3</span><div class="zsg-fineprint"> out of 10</div>
# </div>
# <div class="nearby-schools-info">
# <div class="nearby-schools-name">
# <a class="za-track-event school-name notranslate" data-za-action="School details click" data-za-category="Homes" data-za-label="HDP AB Module" data-za-standard-href="true" href="/boston-ma/schools/taylor-elementary-school-24358/">Taylor Elementary</a>
# </div>
# <div class="nearby-schools-grades">PK-5</div>
# <div class="nearby-schools-distance">0.2 mi</div>
# </div>
# </li>
# <li class="nearby-school clearfix">
# <div class="nearby-schools-rating">
# <span class="gs-rating-number gs-rating-6">6</span><div class="zsg-fineprint"> out of 10</div>
# </div>
# <div class="nearby-schools-info">
# <div class="nearby-schools-name">
# <a class="za-track-event school-name notranslate" data-za-action="School details click" data-za-category="Homes" data-za-label="HDP AB Module" data-za-standard-href="true" href="/milton-ma/schools/charles-s-pierce-middle-school-29743/">Charles S Pierce Middle</a>
# </div>
# <div class="nearby-schools-grades">6-8</div>
# <div class="nearby-schools-distance">1.4 mi</div>
# </div>
# </li>
# <li class="nearby-school clearfix">
# <div class="nearby-schools-rating">
# <span class="gs-rating-number gs-rating-1">1</span><div class="zsg-fineprint"> out of 10</div>
# </div>
# <div class="nearby-schools-info">
# <div class="nearby-schools-name">
# <a class="za-track-event school-name notranslate" data-za-action="School details click" data-za-category="Homes" data-za-label="HDP AB Module" data-za-standard-href="true" href="/boston-ma/schools/dorchester-academy-159152/">Dorchester Academy</a>
# </div>
# <div class="nearby-schools-grades">9-12</div>
# <div class="nearby-schools-distance">0.7 mi</div>
# </div>
# </li>
# </ul>
# </div>
# <p class="attribution">
#     Data by <a href="http://www.greatschools.org/" rel="nofollow" target="_blank">GreatSchools.org</a>
# <a class="zsg-tooltip-launch zsg-icon-circle-question" href="#gs-rating-tip"></a>
# </p>
# <div class="nearby-schools-footer"><div class="zsg-content-item"><a class="za-track-event" data-za-action="Schools on map click" data-za-category="Homes" data-za-label="HDP AB Module" href="/boston-ma/schools/"> More schools in <span class="notranslate">Boston</span></a></div><div class=""><p><strong>About the ratings:</strong> Historically, GreatSchools ratings have been based solely on a comparison of standardized test results for all schools in a given state. As of September 2017, the GreatSchools ratings also incorporate additional information, when available, such as college readiness, academic progress, advanced courses, equity, discipline and attendance data. GreatSchools ratings are designed to be a starting point to help parents compare schools, and should not be the only factor used in selecting the right school for your family. <a href="http://www.greatschools.org/gk/ratings/" rel="nofollow noopener noreferrer" target="_blank">Learn more</a></p><p><strong>Disclaimer: </strong> School attendance zone boundaries are provided by a third party and subject to change. Check with the applicable school district prior to making a decision based on these boundaries. </p></div></div></div></section> <div class="inline-module "> <section class="hdp-ov-inline zsg-content-section collapsible collapsed"> <h2 class="zsg-separator_secondary"> Owner Dashboard </h2> <div class="container owner-dashboard"><div class="upsell-content"><span class="zsg-icon-lock"></span><h3> Do you own this home? See your Owner Dashboard. </h3> <a class="claim-home zsg-button_primary hdp-owner-tab show-lightbox auth-required register" data-after-auth-action-type="Refresh" data-ov-module="Owner Preview - Inline module - Owner Dashboard" data-show-custom-experience-lightbox="true" data-za-label="Owner Preview - Inline module - Owner Dashboard" href="/search/ResurrectionSearchPageWithHomeDetail,initialHomeDetailComponent.$homedetail$HomeDetailsOwnerViewUpsell_0.$links$RegisterLink.sdirect?form:search/ResurrectionSearchPageWithHomeDetail=ZH4sIAAAAAAAAALWTvU8CMRTA32EYxJj4MbsxX9Q4uLgoMRAJIZ4Jholy98Bir6-86_GxmLjg4Kq7gyN_lLo7u3ooYmJISEC6NH2v7a-_l77hO6S7IQBkHKhkIxTsX2W9r6ksmnhKZJHdJEFJlErk-UxKjcO-0KSlL1RR6uvIQ-5IH90WSZ2TjL4l7o8ysG6QIxlZDDxia7pFB46kllYKlacQc2iFVCcUGtKorfvzjDJTctD2z9Ekx7y4HvksjZWkIWPGuUIQMWy2REe4SuimW9AWm8hbb0_PH7d3hylwCpDuCBVjj2Hjd18pDuvIg-HjztrDy30KoGdWBrXXbsuBy2iiX2FhzMg_ltkLMiXR2d_dO3BFEEqdLI5jqYIF6sAOVGfCEtOGVDgHbnuCG13_bWy6VQfyM6HzGqnlGv3F1f7TZXq5zDI_xHQkLbEVpxPPFm7I1QZjO0bt96M23MBoOJ90v58CXAQAAA%7E%7E" id="register_opener_25" rel="nofollow">I'm the owner. Show me!</a> </div></div></section> </div> <div class="loading" id="hdp-building-permits"></div><div class="lightbox-hdp-ad-module zsg-content-component" data-load-ad="400"><div class="google-ad-config" data-frame-id="gpt-ad-98d83790-9347-40a3-830a-4156a3ba4004" id="gpt-ad-98d83790-9347-40a3-830a-4156a3ba4004-config" style="display: none;">{"targetDiv":"gpt-ad-98d83790-9347-40a3-830a-4156a3ba4004","slot":"zillow/property_details/buy_agent/property_1","network":"7449","sizes":["fluid"],"targets":{"aamgnrc1":"19 Ellison Ave","bd":"5","fsbid":"2","city":"Boston","proptp":"sfh","vers":"ADS_Tagless:Casale_On,SHO_MOBILE_WEB_NAV_ADS:AFTER_2ND,SHO_ADS_AND_TRACKING_PIXELS:CONTROL,SRP_DESKTOP_ADS_VARIANTS:VARIANT_B,SHO_DESKTOP_EXPOSED_FILTERS:CONTROL,SRP_MWEB_ADS_VARIANTS:VARIANT_B,SHO_DESKTOP_NAV_AD_LOAD_ORDER:EARLIER_AD_REQUEST,SHO_NAV_AD_BACKGROUND:GRAY,HDP_NativePhotoplayer:ON,HDP_FAF_TELECOM:CONTROL,HDP_CONTENT_REGROUP:CONTROL,HDP_AD_BELOW_MODULES:ON_ABOVE_CONTACT_MID_RENDER,HDP_SERVICE_FSBA:CONTROL,HDP_SERVICE_FSBA_MOBILE:ON,HDP_SERVICE_NFS:CONTROL,SEOTEST__HDP_EXPANDED:CONTROL","pid":"59138273","lot":"1","zestibuck":"500-599k","listtp":"buy_agent","searchtp":"zipcode","filtered":"false","zguidh":"-1813651971815150048","sqftrange":"1500-1999","price":"699900","sqft":"1772","posting_url":"","state":"MA","mlong":"-71.0897405","pis":"1","cnty":"Suffolk","prange":"600-699k","zip":"02126","mlat":"42. ...
#         window.ZILLOW_AB_TEST = window.ZILLOW_AB_TEST || {};
#     </script><div class="zsg-nav-sub-wrapper"><div class="zsg-nav-sub" id="search-anchor"><div class="zsg-toolbar" id="search-bar-container"><ul class="zsg-toolbar-left zsg-toolbar-tabs zsg-tabs"><li class="search-box-content"><form action="/search/RealEstateSearch.htm" class="zsg-searchbox" method="get" role="search"><label class="hide-visually" for="citystatezip">Search</label><input autocorrect="off" id="citystatezip" name="citystatezip" placeholder="Address, Neighborhood, or ZIP" type="text" value="Boston MA 02126"/><input id="regionId" name="regionId" type="hidden"/><!-- POI Autocomplete data --><input id="acCategory" name="acCategory" type="hidden"/><input id="acCoord" name="acCoord" type="hidden"/><div class="zsg-searchbox-content-container"><button aria-label="Submit" class="zsg-searchbox-content zsg-search-button" type="submit"><i class="zsg-icon-searchglass"></i></button></div><script src="https://www.zillowstatic.com/static-search/cc047d4/static-search/js/ads-by-google.js" type="text/javascript"></script></form></li><li class="zsg-nav-item hide" id="search-sort-bar"></li></ul><ul class="zsg-toolbar-right"><li id="save-search-button"><fieldset class="filter-menu save-search"><legend data-za-label="Save search"><a class="zsg-lightbox-show zsg-link_primary" data-za-href="!ignore" data-za-label="Save search" data-za-label-submit="Save Search Toolbox submit" href="#saved-search-lightbox"><div> Save Search </div></a></legend></fieldset></li><li id="fav-control-back"><a class="zsg-toolbar-button zsg-button_primary track-ga-event" data-za-action="Back Search Click" data-za-category="Followed Homes" data-za-label="SavedHomes Map" href="/homes/" rel="nofollow" title="Back to Search"><span class="leftarrow"></span>Back to Search</a></li><li class="search-nav-button" id="fav-control-myhome"><a class="zsg-toolbar-button zsg-button_primary track-ga-event show-lightbox" data-after-auth-action-type="Link" data-za-action="Saved Homes Click" data-za-category="Search" data-za-label="SavedHomes Map" href="/savedhomes/" id="register_opener" rel="nofollow" title="Saved Homes"> Saved Homes (<span data-count="0" id="saved-homes-count">0</span>) </a></li></ul></div></div></div><div class="search-content-container map-controls-simplified " id="container"><div class="active-view"><div class="property-data-column yui3-u " id="c-column"><div class="inner-property-data-column" id="inner-c-column"><div class="search-list-col" id="list-container-column"><div class="active-view"><div class="" data-zmm-page="Search-List" id="list-results-container"><div class="list-container has-selected-listing " id="list-container"><div id="inner-list-container"><div class="hide nav-ad-bg-gray" id="nav-ad-container"><div id="list-nav-ad-loading"><span class="zsg-loading-spinner zsg-loading-spinner_gray"></span> Loading </div><div class="nav-ad-property-listing" id="nav-ad-gpt-container"><div class="google-ad-config" data-frame-id="gpt-ad-53d7ebcb-9425-4af1-a4a3-e3d51914579b" id="gpt-ad-53d7ebcb-9425-4af1-a4a3-e3d51914579b-config" style="display: none;">{"targetDiv":"gpt-ad-53d7ebcb-9425-4af1-a4a3-e3d51914579b","slot":"zillow/search_results/buy_general/n_right_p1","network":"7449","sizes":"fluid","targets":{"aamgnrc1":"19 Ellison Ave","bd":"5","fsbid":"2","city":"Boston","proptp":"sfh","vers":"ADS_Tagless:Casale_On,SHO_MOBILE_WEB_NAV_ADS:AFTER_2ND,SHO_ADS_AND_TRACKING_PIXELS:CONTROL,SRP_DESKTOP_ADS_VARIANTS:VARIANT_B,SHO_DESKTOP_EXPOSED_FILTERS:CONTROL,SRP_MWEB_ADS_VARIANTS:VARIANT_B,SHO_DESKTOP_NAV_AD_LOAD_ORDER:EARLIER_AD_REQUEST,SHO_NAV_AD_BACKGROUND:GRAY,HDP_NativePhotoplayer:ON,HDP_FAF_TELECOM:CONTROL,HDP_CONTENT_REGROUP:CONTROL,HDP_AD_BELOW_MODULES:ON_ABOVE_CONTACT_MID_RENDER,HDP_SERVICE_FSBA:CONTROL,HDP_SERVICE_FSBA_MOBILE:ON,HDP_SERVICE_NFS:CONTROL,SEOTEST__HDP_EXPANDED:CONTROL","pid":"59138273","lot":"1","zestibuck":"500-599k","listtp":"buy_agent","searchtp":"zipcode","filtered":"false","zguidh":"-1813651971815150048","targetRegionId":"58640","sqftrange":" ...
#         {"endDate":"2018-07-24T18:00:00-07:00","@type":"Event","name":"Open House - 5:00 - 6:00 PM","description":"Open House","location":{"geo":{"@type":"GeoCoordinates","latitude":42.275738,"longitude":-71.10145},"address":{"streetAddress":"56 Monterey Ave","@type":"PostalAddress","postalCode":"02126","addressLocality":"Boston","addressRegion":"MA"},"@type":"Place","name":"56 Monterey Ave"},"@context":"http:\/\/schema.org\/","url":"https:\/\/www.zillow.com\/homedetails\/56-Monterey-Ave-Boston-MA-02126\/59137867_zpid\/","startDate":"2018-07-24T17:00:00-07:00"}
#     </script></div><a class="zsg-photo-card-overlay-link routable hdp-link routable mask hdp-link" href="/homedetails/56-Monterey-Ave-Boston-MA-02126/59137867_zpid/"></a><div class="zsg-photo-card-img"><ul class="zsg-list_inline zsg-photo-card-badge"><li class="">Open: Tue. 5-6pm</li></ul><img data-src="https://photos.zillowstatic.com/p_e/IS2j3a1v9laolh1000000000.jpg" src="..."/></div><div class="zsg-photo-card-actions "><a class="save-home-operation" data-address="56 Monterey Ave , Boston, MA 02126" data-after-auth-action-type="Event" data-after-auth-global-event="favoriteManager:addFavoriteProperty" data-auth-process="searchlistcard/save" data-fm-callback="windowReloadSuccessHandler" data-fm-zpid="59137867" data-save-home-reg-success-handler="resultListSaveFavoriteSuccessHandler" data-show-home-owner-lightbox="false" data-target-id="register" data-za-label="Save Map:List" href="/myzillow/UpdateFavorites.htm?zpid=59137867&amp;operation=add&amp;ajax=false" id="register_opener_39" rel="nofollow" title="Save this home"><span class="image-control sprite-heart-line new-save-hide-icon larger-save"></span></a></div></div><div class="minibubble template hide"><!--{"bed":3,"miniBubbleType":1,"image":"https:\\/\\/photos.zillowstatic.com\\/p_a\\/IS2j3a1v9laolh1000000000.jpg","sqft":1040,"label":"$410K","isPropertyTypeVacantLand":false,"datasize":9,"title":"$410K","bath":1.0,"flexData":[1,"Tue. 5\-6pm"]}--></div></article></li><li><article class="zsg-photo-card photo-card zsg-aspect-ratio type-not-favorite" data-grouped="" data-latitude="42277248" data-longitude="-71073170" data-pgapt="ForSale" data-photocount="21" data-sgapt="For Sale (Broker)" data-zillowowned="" data-zpid="2089692115" id="zpid_2089692115"><div class="zsg-photo-card-content zsg-aspect-ratio-content" itemscope="" itemtype="http://schema.org/SingleFamilyResidence"><span class="hide" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span itemprop="streetAddress">24 Ellison Ave # 2</span><span itemprop="addressLocality"> Boston </span><span itemprop="addressRegion">MA </span><span class="hide" itemprop="postalCode">02126</span></span><span itemprop="geo" itemscope="" itemtype="http://schema.org/GeoCoordinates"><meta content="42.277248" itemprop="latitude"/><meta content="-71.07317" itemprop="longitude"/></span><div class="zsg-photo-card-caption"><h4 class="zsg-photo-card-spec"><span class="zsg-photo-card-status"><span class="zsg-icon-for-sale"></span>Condo For Sale</span></h4><p class="zsg-photo-card-spec"><span class="zsg-photo-card-price">$495,000</span><span class="zsg-photo-card-info">3 bds <span class="interpunct">·</span> 1 ba <span class="interpunct">·</span> 1,253 sqft</span></p><p class="zsg-photo-card-spec"><span class="zsg-photo-card-address">24 Ellison Ave # 2, Boston, MA</span></p><p class="zsg-photo-card-spec"><span class="zsg-photo-card-broker-name">Coldwell Banker Residential Brokerage - Milton</span></p></div><a class="zsg-photo-card-overlay-link routable hdp-link routable mask hdp-link" href="/homedetails/24-Ellison-Ave-2-Boston-MA-02126/2089692115_zpid/"></a><div class="zsg-photo-card-img"><ul class="zsg-list_inline zsg-photo-card-badge"><li class="">79 days on Zillow</li></ul><img data-src="https://photos.zillowstatic.com/p_e/ISy7su7v1xfsml1000000000.jpg" src="..."/></div><div class="zsg-photo-card-actions "><a class="save-home-operation" data-address="24 Ellison Ave # 2, Boston, MA 02126" data-after-auth-action-type="Event" data-after-auth-global-event="favoriteManager:addFavoriteProperty" data-auth-process="searchlistcard/save" data-fm-callback="windowReloadSuccessHandler" data-fm-zpid="2089692115" data-save-home-reg-success-handler="resultListSaveFavoriteSuccessHandler" data-show-home-owner-lightbox="false" data-target-id="register" data-za-label="Save Map:List" href="/myzillow/UpdateFavorites.htm?zpid=2089692115&amp;operation=add&amp;ajax=false" id="register_opener_40" rel="nofollow" title="Save this home"><span class="imag ...
#         if (sessionStorage) {
#             sessionStorage.setItem('useWebPushUpsell', 'false');
#         }
# ...
#         window.zSDLConfig = {"staticDomain":"https://www.zillowstatic.com/","versions":{"admin-account-toolsStatic":"static-admin-account-tools/c1a3188","adtech-landingStatic":"static-adtech-landing/null","advStatic":"static-adv/2ef0d63","adviceStatic":"static-advice/25e5aad","agentteamsStatic":"static-agentteams/db3e983","app-upsellStatic":"static-app-upsell/04630c5","app-viewsStatic":"static-app-views/e7c3391","async-contentStatic":"static-async-content/36c5773","bdpStatic":"static-bdp/5ff8b95","best-timeStatic":"static-best-time/c479a30","bproStatic":"static-bpro/3cf9b7b","building-adminStatic":"static-building-admin/34d58c6","chinese-landing-pageStatic":"static-chinese-landing-page/8ee294a","claimStatic":"static-claim/a2ad0b8","community-pillarStatic":"static-community-pillar/cedeb1e","complaintsStatic":"static-complaints/e92a505","contact-formStatic":"static-contact-form/7958c5f","contactsStatic":"static-contacts/55f0ac7","email-a-friendStatic":"static-email-a-friend/847f564","ecuiStatic":"static-ecui/43a4038","formattersStatic":"static-formatters/34b921e","gtmStatic":"static-gtm/c9391e2","hdpStatic":"static-hdp/a6a1abf","hdp-legacy-shimStatic":"static-hdp-legacy-shim/257c863","homepageStatic":"static-homepage/3727afe","homevaluesStatic":"static-homevalues/4288ddb","inspectionsStatic":"static-inspections/8ed1066","instant-offerStatic":"static-instant-offer/1779857","keystoneStatic":"static-keystone/a98b99a","lazy-image-loaderStatic":"static-lazy-image-loader/ec0328d","managed-lifecycleStatic":"static-managed-lifecycle/e29d665","mapStatic":"static-map/d81c3c9","mobile-landingpageStatic":"static-mobile-landingpage/2bfadf9","modalsStatic":"static-modals/4cdd552","npmStatic":"static-npm/d369a91","santas-houseStatic":"static-santas-house/9b25f76","nc-mapStatic":"static-nc-map/8b727d1","neighborhoodStatic":"static-neighborhood/89348a6","paStatic":"static-pa/a17d2a7","pagewrapperStatic":"static-pagewrapper/fc76d74","paparazziStatic":"static-paparazzi/0a7c207","permitsStatic":"static-permits/0ea0805","personalizationStatic":"static-personalization/a5b0dd2","posting-pathStatic":"static-posting-path/eafd2cf","pricing-toolStatic":"static-pricing-tool/d22743d","profileStatic":"static-profile/bc77a87","property-mapsStatic":"static-property-maps/b63219a","property-photosStatic":"static-property-photos/f7b1c20","rent-affordabilityStatic":"static-rent-affordability/a556e8a","renterprofileStatic":"static-renterprofile/8c5d2c6","rentvsbuyStatic":"static-rentvsbuy/6dc0b2d","richdataStatic":"static-richdata/4440f17","sales-historyStatic":"static-sales-history/87fa5c8","schoolsStatic":"static-schools/18d5a82","searchStatic":"static-search/cc047d4","searchbarStatic":"static-searchbar/12c3c54","sellerStatic":"static-seller/99cb128","seller-landingStatic":"static-seller-landing/a07313d","seopagesStatic":"static-seopages/2ab1829","smart-bannerStatic":"static-smart-banner/594889c","social-media-toolsStatic":"static-social-media-tools/dcd85c8","third-party-adsStatic":"static-third-party-ads/ec54100","topnavStatic":"static-topnav/516acd4","user-accountStatic":"static-user-account/4faeb77","validation-regexesStatic":"static-validation-regexes/b3d0b3a","vcrStatic":"static-vcr/57e2860","video-landingStatic":"static-video-landing/3309f64","webview-supportStatic":"static-webview-support/c3a282d","widgetsStatic":"static-widgets/b68ec6f","yuiStatic":"static-yui/5b7360e","zsgStatic":"static-zsg/9c6fb5d","hiStatic":"static-hi/236b039","static":"static/b20c067"}};
#     </script><script>if(typeof ClientProfiler!=="undefined"){ClientProfiler.profile("border seed finished")};</script><div class="hide" id="perimeterX"><noscript><div height="1" style="position:fixed; top:0; left:0; display:none" width="1"><img src="//collector-PXHYx10rg3.perimeterx.net/api/v1/collector/noScript.gif?appId=PXHYx10rg3"/></div></noscript></div><div class="zsg-hide" id="googleAutoSignInNode"></div><script>if(!window.ProxiedReactAppConfig) { window.ProxiedReactAppConfig = {}; };window.ProxiedReactAppConfig.staticDomain="https://www.zillowstatic.com/";if(!window.ProxiedReactAppConfig["static-global-redux-store"]) { window.ProxiedReactAppConfig["static-global-redux-store"] = {}; };window.ProxiedReactAppConfig["static-global-redux-store"]["global-redux-store-loader"]={"loggedIn":"false"};</script><script src="https://www.zillowstatic.com/static-global-redux-store/LIVE/overall-commons-626b068f6c.js"></script><script src="https://www.zillowstatic.com/static-global-redux-store/LIVE/global-redux-store-loader/app-b1f5cf7092.js"></script><script>if(!window.ProxiedReactAppConfig) { window.ProxiedReactAppConfig = {}; };window.ProxiedReactAppConfig.staticDomain="https://www.zillowstatic.com/";if(!window.ProxiedReactAppConfig["static-user-session-store"]) { window.ProxiedReactAppConfig["static-user-session-store"] = {}; };window.ProxiedReactAppConfig["static-user-session-store"]["user-session-store-loader"]={"loggedIn":"false"};</script><script src="https://www.zillowstatic.com/static-user-session-store/LIVE/overall-commons-d33db02c1a.js"></script><script src="https://www.zillowstatic.com/static-user-session-store/LIVE/user-session-store-loader/app-1ba188d3c7.js"></script><div class="hide" id="analytics"><!-- SiteCatalyst code version: H.22.1 Copyright 1997-2010 Adobe, Inc. More info available at http://www.omniture.com --><script>
# window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
# </script><noscript><img alt="" height="0" src="https://sb.scorecardresearch.com/b2?c1=2&amp;c2=6036206&amp;c3=&amp;c4=www.zillow.com/homes/for_sale/Boston-MA-02126/59138273_zpid/58640_rid/42.300388,-71.060172,42.251615,-71.119309_rect/13_zm/&amp;c5=&amp;c6=&amp;c15=&amp;cv=1.3&amp;cj=1" style="display:none" width="0"/></noscript></div><script src="https://www.zillowstatic.com/vstatic/b20c067/static/js/wombo-seed-concat.js" type="text/javascript"></script><script>window.zBodyScripts=(function(){ClientProfiler.profile("body script request start");YUI().use("event-base","event-custom-base","map-image-overlay-layer","node-base","yui-later","z-community-overlay-manager","zillow-node-methods",function(Y,meta){if(meta.success!==true){Y.message(meta.msg,"warn");return}YUI.applyConfig({csrfToken:"Mpz4vdGBX4mLsNn7k7Nq8ehEwt6sfatFRIXRbB7kR7s"});if(YUI.GlobalConfig.debug){if(YUI.zDebugEvents===undefined){YUI.zDebugEvents={}}if(YUI.GlobalConfig.zonConsole&&Y.log){window.zonLogString=window.zonLogString||"Zon Log Start";window.originalLog=Y.log;window.zonLog=function(a,b,c,d,e){if(c!=="attribute"&&c!=="base"&&c!=="plugin"){window.zonLogString+="\n";window.zonLogString+=a+", "+b+", "+c+", "+d+", "+e}window.originalLog.call(this,a,b,c,d,e)};Y.log=window.zonLog}function hookIntoZDebugEvents(YObject){YObject.zFire=YObject.fire;YObject.fire=function(t){YUI.zDebugEvents[t]=(!YUI.zDebugEvents[t]?1:YUI.zDebugEvents[t]+1);YObject.zFire.apply(this,[].slice.call(arguments))}}hookIntoZDebugEvents(Y.Global);hookIntoZDebugEvents(Y)}ClientProfiler.profile("body script callback start");Y.use("event-base",function(Y){Y.on("domready",ClientProfiler.profile,Y,"dom ready");Y.after("domready",ClientProfiler.profile,Y,"dom ready complete")});Y.on("domready",function(e){Y.use("event-custom","keystone-event-source","z-account-popup-message","z-home-search-bar","z-rentals-activate-listing-banner","z-save-home-reg-dialup_ACT-616","z-search-app","z-search-detail-lightbox-app","z-top-nav",function(Y){window.KES("set","targetUrl","https://keystone.zillow.com/event");window.KES("set","configData",{_guid:"4d0f43c8-e916-40db-bcae-24ceb3ee5cc5"});Y.Global.publish("Keystone:TrackedEvent",{emitFacade:true,defaultFn:function(e){if(e.action==="set"||(e.action==="send"&&"hdp_contact, favorite, hdp, dwell, search, start_video, tour_start, tour_dwell, tour_pano_view, poi_typeahead, experiment_viewed".indexOf(e.key)!==-1)){window.KES(e.action,e.key,e.data,e.namespace)}}});Y.fire("keystoneReady");(function(){var navTopTemp=Y.one(".nav-top_temp"),navTopFull=Y.one(".nav-top_full"),isHeaderPinnable;if(navTopTemp&&navTopFull){navTopTemp.replace(navTopFull)}isHeaderPinnable=Y.one("body").hasClass("pinnable-header_enabled");new Y.Z.TopNav({priorityInitEvent:"priorityUiReady",preventScrollBubbling:isHeaderPinnable,wideNavCapable:true,fetchUserNav:false})})();Y.Z.AccountPopupMessage.init();Y.Z.HomeSearchBar.init({appendOwnerParam:false});new Y.Z.RentalsActivateListingBanner();var _searchAppCfg={staticConfig:{renderedBoundingRect:[-71.119309,42.251615,-71.060172,42.300388],userMode:"defaultList",mapAddons:{addonsEnabled:true,defaultAddon:"schools",addons:{builder_map_layer:{configUrl:"https://s.zillowstatic.com/community-overlay-config/LATEST/community_config.json",enabled:true},universities:{resultMgr:"z-universities-result-mgr",resultMgrConfig:{list:[{name:"02126",lon:0,lat:0}]},enabled:false},schools:{resultMgr:"z-schools-result-mgr",paramKeys:["sch","sc"],plugin:"z-plugin-schools-map-addon",defaultState:{sc:[],sch:{lvl:"",rat:1,bnd:"",typ:"",iu:"u"}},maxZoom:20,minZoom:6,fillOrMask:"mask",enabled:true}},activeAddon:""},mapRollupThreshold:500,mapKey:"AmdvKO2hNoyLePakiVzRBZiGPKCxV6MtwWneohoPfmXclTaRTzvT6_Ict5-PBHO6",zoom:11,searchPageTitle:"02126 Real Estate &amp; Homes For Sale - 58 Homes | Zillow",currentRate:4.39},viewsBeforeReload:10,isFirstSearchPageVisit:true};var htmlDecode=function(encodedString){var textArea=document.createElement("textarea");textArea.innerHTML=encodedString;retu ...
# if(!window.ZMOB_nativeAPI||(window.ZMOB_nativeAPI&&!window.ZMOB_nativeAPI.trackWebviewEvent)){(function(){window._gaq=window._gaq||[];window._gaqBackup=window._gaqBackup||[];window._gaq.push(["_setAccount","UA-21174015-1"]);window._gaq.push(["_setDomainName",".zillow.com"]);window._gaqBackup=[["_setCustomVar",6,"Zip","02126"],["_setCustomVar",15,"Listing Type","For Sale (Broker)"],["_setCustomVar",81,"Video ID","No Video"],["_setCustomVar",8,"Address","19 Ellison Ave"],["_setCustomVar",22,"AccountCreationDate","",1],["_setCustomVar",14,"HDP Type","ForSale"],["_setCustomVar",1,"Guid","4d0f43c8e91640dbbcae24ceb3ee5cc5",1],["_setCustomVar",66,"PageType","Search"],["_setCustomVar",71,"FilterSettings",'{"Preforeclosure":"1","PriceRange":",","ListId":"","RentalCheapApartmentsBoolean":"0","PremarketForeclosure":"1","ListingTypeGroup":"111101","MonthlyPaymentRange":",","BathsRange":",","PhotosBoolean":"0","RentalParkingAvailableBoolean":"0","RentalInUnitLaundryBoolean":"0","RentalPetsAllowedBoolean":"0","YearBuiltRange":",","DaysOnSelection":"any","HomeTypeGroup":"111111","SearchPageTypeSelection":"homes","DataSourceSelection":"all","StatusFlagGroup":"110001","RentalStudioApartmentsBoolean":"0","HOARange":",","SortSelection":"globalrelevanceex","OffersBoolean":"0","LotSizeRange":",","BedsRange":",","ShowCondoBuildingsBoolean":"0","AttributeTerms":"","ShowRentalBuildingsBoolean":"0","ShowPendingBoolean":"0","RentalIncomeRestrictedBoolean":"0","PriceReductionsBoolean":"0","SqFtRange":",","SingleStory":"0","RentalFurnishedApartmentsBoolean":"0"}'],["_setCustomVar",5,"City","Boston"],["_setCustomVar",7,"Neighborhood",""],["_setCustomVar",25,"Device Type","Desktop"],["_setCustomVar",99,"SearchListResultCount","4"],["_setCustomVar",93,"SEO Test 4","SEOTEST__HDP_SERVICE_OFF_MARKET.CONTROL",1],["_setCustomVar",3,"State","MA"],["_setCustomVar",91,"SEO Test 2","SEOTEST__SHO_MAGIC_CARPET_SEO.HDP_IN_LIGHTBOX",1],["_setCustomVar",10,"Price","$699,900"],["_setCustomVar",23,"SearchTypes","ForSale,MakeMeMove,PreMarket",2],["_setCustomVar",12,"UserType","Unrecognized",2],["_setCustomVar",111,"3D home","No 3D Home"],["_setCustomVar",80,"Owner or Public","Public"],["_setCustomVar",60,"A/B Test 20","SHO_React_Mobile_Search_List.CONTROL",1],["_setCustomVar",125,"ZestimateListPriceAgreement","LPHigh15to30"],["_setCustomVar",2,"House ID / Zpid","59138273"],["_setCustomVar",4,"County","Suffolk"],["_setCustomVar",24,"ListingFeatureType","organic"],["_setCustomVar",58,"A/B Test 18","ProfilePageRegionFeature.DISABLED",1],["_setCustomVar",59,"A/B Test 19","PERS_SHARED_FAVORITES.CONTROL",1],["_setCustomVar",39,"A/B Test 14","Z3D_HDP_PhotoWall.ON_PanoFourthSlot",1],["_setCustomVar",40,"A/B Test 15","UX-SatisfactionSurvey.CONTROL",1],["_setCustomVar",56,"A/B Test 16","AB_DASHBOARD_AA_TEST.ON",1],["_setCustomVar",57,"A/B Test 17","tr_top_nav_mweb.CONTROL",1],["_setCustomVar",50,"A/B Test 10","TR_WHAT_I_LOVE.PERSONAL_TOUCH",1],["_setCustomVar",36,"A/B Test 11","HRS_HDP_RECS_CONFIG.CONTROL",1],["_setCustomVar",37,"A/B Test 12","PERS_GRS.CONTROL",1],["_setCustomVar",38,"A/B Test 13","SXP_DelayJS.AFTER_LOAD",1],["_setCustomVar",27,"TrackingContactModule","bal4\\HDP:-Lightbox-C-Column\\1\\1112\\21\\0000"],["_setCustomVar",26,"BrokerId","2"],["_setCustomVar",18,"SearchScenario","Region-Zip"],["_setCustomVar",69,"FullReferringURL",""],["_setCustomVar",49,"A/B Test 9","HDP_SERVICE_FSBA.CONTROL",1],["_setCustomVar",46,"A/B Test 6","NC_BUILDER_MAP_LAYER.HDP_AND_SEARCH_MAP",1],["_setCustomVar",65,"A/B Test 25","PR_CONTACT_FORM.WARMER_BUTTON",1],["_setCustomVar",45,"A/B Test 5","HDP_SERVICE_FSBA_APP_V2.CONTROL",1],["_setCustomVar",48,"A/B Test 8","CDP_SERVICE.ON",1],["_setCustomVar",47,"A/B Test 7","WIDGET_SCHOOL_PARAM.SchoolFiltersOpen",1],["_setCustomVar",42,"A/B Test 2","NC_MWEB_LOWERPROMO.CONTROL",1],["_setCustomVar",61,"A/B Test 21","URLShareTracking.CONTROL",1],["_setCustomVar",9,"PropertyType","Single Family"],["_setCustomVar",41,"A/B Test 1","ACT_GOOGLE_1_TAP.REG_LOGIN" ...
# var _comscore=_comscore||[];_comscore.push({c1:2,c2:"6036206",c3:"",c4:"www.zillow.com/homes/for_sale/Boston-MA-02126/59138273_zpid/58640_rid/42.300388,-71.060172,42.251615,-71.119309_rect/13_zm/",c5:"",c6:"",c15:""});var _comscoreBackup=_comscoreBackup||[];_comscoreBackup.push.apply(_comscoreBackup,_comscore);setTimeout(function(){var b=document.createElement("script");b.type="text/javascript";b.setAttribute("async",true);b.src=(document.location.protocol=="https:"?"https://sb":"http://b")+".scorecardresearch.com/beacon.js";var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(b,a)},100);
#
# // --></script>
# <!-- H:034  T:186ms  S:538531  R:Mon Jul 23 19:57:41 PDT 2018  B:5.0.54975-master.381c5c1~delivery_ready.3813e63 -->

# %%
name = soup.find('span', attrs={'class': 'hdp-fact-value'})
print(name)
# Out:
# <span class="hdp-fact-value">5</span>
